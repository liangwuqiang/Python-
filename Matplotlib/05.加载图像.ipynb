# %% [markdown]
# # 05 加载图像

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline

# %% [markdown]
# ![臭虫](stinkbug.png)

# %% [markdown]
# ### 导入图像

# %%
img = mpimg.imread('stinkbug.png')  # 读取图像

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
img.dtype
# Out:
# dtype('float32')

# %% [markdown]
# ### 显示图像

# %%
imgplot = plt.imshow(img)
